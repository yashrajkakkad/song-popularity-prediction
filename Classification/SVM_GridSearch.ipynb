# %% [markdown]
# <a href="https://colab.research.google.com/github/yashrajkakkad/ml-spotify/blob/master/SVM_GridSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/ml-spotify/data.csv')
df.head()
# Out:
#    acousticness                    artists  ...  valence  year
# 0      0.991000            ['Mamie Smith']  ...   0.6340  1920
# 1      0.643000  ["Screamin' Jay Hawkins"]  ...   0.9500  1920
# 2      0.993000            ['Mamie Smith']  ...   0.6890  1920
# 3      0.000173        ['Oscar Velazquez']  ...   0.0422  1920
# 4      0.295000                   ['Mixe']  ...   0.2990  1920
#
# [5 rows x 19 columns]

# %%
df.describe()
# Out:
#         acousticness   danceability  ...        valence           year
# count  174389.000000  174389.000000  ...  174389.000000  174389.000000
# mean        0.499228       0.536758  ...       0.524533    1977.061764
# std         0.379936       0.176025  ...       0.264477      26.907950
# min         0.000000       0.000000  ...       0.000000    1920.000000
# 25%         0.087700       0.414000  ...       0.311000    1955.000000
# 50%         0.517000       0.548000  ...       0.536000    1977.000000
# 75%         0.895000       0.669000  ...       0.743000    1999.000000
# max         0.996000       0.988000  ...       1.000000    2021.000000
#
# [8 rows x 15 columns]

# %%
df["key"] = df["key"].astype("category")
df = pd.get_dummies(df, columns=["key"])
df.head()
# Out:
#    acousticness                    artists  danceability  ...  key_9  key_10  key_11
# 0      0.991000            ['Mamie Smith']         0.598  ...      0       0       0
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852  ...      0       0       0
# 2      0.993000            ['Mamie Smith']         0.647  ...      0       0       0
# 3      0.000173        ['Oscar Velazquez']         0.730  ...      0       0       0
# 4      0.295000                   ['Mixe']         0.704  ...      0       1       0
#
# [5 rows x 30 columns]

# %%
df["mode"] = df["mode"].astype("category")
df = pd.get_dummies(df, columns=["mode"])
df.head()
# Out:
#    acousticness                    artists  ...  mode_0  mode_1
# 0      0.991000            ['Mamie Smith']  ...       1       0
# 1      0.643000  ["Screamin' Jay Hawkins"]  ...       1       0
# 2      0.993000            ['Mamie Smith']  ...       0       1
# 3      0.000173        ['Oscar Velazquez']  ...       0       1
# 4      0.295000                   ['Mixe']  ...       1       0
#
# [5 rows x 31 columns]

# %%
len(df.columns), df.columns
# Out:
# (31, Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#         'explicit', 'id', 'instrumentalness', 'liveness', 'loudness', 'name',
#         'popularity', 'release_date', 'speechiness', 'tempo', 'valence', 'year',
#         'key_0', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5', 'key_6', 'key_7',
#         'key_8', 'key_9', 'key_10', 'key_11', 'mode_0', 'mode_1'],
#        dtype='object'))

# %%
mean_popularity = 42
y_prime = [1 if i >= mean_popularity else 0 for i in df["popularity"]]
# y = pd.concat([df.id, pd.Series(y_prime, name="popularity")], axis=1)
y_popl = pd.concat([pd.Series(y_prime, name="popularity")], axis=1)
# y_popl["popularity"].value_counts()
y = y_popl["popularity"]

# %%
drop_cols = ["id", "release_date", "popularity", "artists", "name"]
X = df.drop(drop_cols, axis=1)
len(X.columns), X.columns
# Out:
# (26,
#  Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
#         'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#         'valence', 'year', 'key_0', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5',
#         'key_6', 'key_7', 'key_8', 'key_9', 'key_10', 'key_11', 'mode_0',
#         'mode_1'],
#        dtype='object'))

# %%
# drop_features = ["acousticness", "explicit"]
# X = X.drop(drop_features, axis=1)
# len(X.columns), X.columns

# %%
df.describe()
# Out:
#         acousticness   danceability  ...         mode_0         mode_1
# count  174389.000000  174389.000000  ...  174389.000000  174389.000000
# mean        0.499228       0.536758  ...       0.297616       0.702384
# std         0.379936       0.176025  ...       0.457211       0.457211
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.087700       0.414000  ...       0.000000       0.000000
# 50%         0.517000       0.548000  ...       0.000000       1.000000
# 75%         0.895000       0.669000  ...       1.000000       1.000000
# max         0.996000       0.988000  ...       1.000000       1.000000
#
# [8 rows x 27 columns]

# %%
X.shape, y.shape
# Out:
# ((174389, 26), (174389,))

# %%
scaler = StandardScaler().fit(X)
X = scaler.transform(X)
X.shape
# Out:
# (174389, 26)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
# %%time
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, classification_report

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'],
                     'random_state': [42],
                     'gamma': [1e-4, 1e-3, 1e-2, 1e-1, 1e0],
                     'C': [0.1, 1, 10, 100, 1000]
                     }]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        SVC(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train[:10000], y_train[:10000])

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_true, y_pred))
    print()

# svm = LinearSVC(random_state=42, tol=1e-5, max_iter=10000)
# svm.fit(X_train[:50000], y_train[:50000])
# # print("Train accuracy of svm algo:", svm.score(X_train, y_train))
# # print("Test accuracy of svm algo:", svm.score(X_test, y_test))


# cv_scores = cross_val_score(svm, X_train[:100000], y_train[:100000], cv=3)
# print("Cross Validation scores - ", cv_scores)

# y_train_pred = cross_val_predict(svm, X_train[:100000], y_train[:100000])

# confusion_matrix = confusion_matrix(y_train[:100000], y_train_pred)
# print("Confusion matrix\n", confusion_matrix)

# p_score = precision_score(y_train[:100000], y_train_pred)
# rc_score = recall_score(y_train[:100000], y_train_pred)
# f1_score = f1_score(y_train[:100000], y_train_pred)
# p_score, rc_score, f1_score
# print("Recall score = ", rc_score)
# print("Precision score = ", p_score)
# print("F1 score = ", f1_score)

# print("Classification report\n")
# print(classification_report(y_train[:100000], y_train_pred))
# Out:
# # Tuning hyper-parameters for precision
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best parameters set found on development set:
#
# {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
#
# Grid scores on development set:
#
# 0.368 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.368 (+/-0.000) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.723 (+/-0.029) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.746 (+/-0.043) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.368 (+/-0.000) for {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.368 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.724 (+/-0.030) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.726 (+/-0.030) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.725 (+/-0.024) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.695 (+/-0.025) for {'C': 1, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.723 (+/-0.031) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.720 (+/-0.022) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.734 (+/-0.022) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.695 (+/-0.016) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.668 (+/-0.038) for {'C': 10, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.723 (+/-0.027) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.728 (+/-0.024) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.724 (+/-0.022) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.667 (+/-0.016) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.667 (+/-0.037) for {'C': 100, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.718 (+/-0.028) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.735 (+/-0.022) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.711 (+/-0.027) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.652 (+/-0.018) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.667 (+/-0.036) for {'C': 1000, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# [[25589   282]
#  [ 8097   910]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.99      0.86     25871
#            1       0.76      0.10      0.18      9007
#
#     accuracy                           0.76     34878
#    macro avg       0.76      0.55      0.52     34878
# weighted avg       0.76      0.76      0.68     34878
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.558 (+/-0.004) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.528 (+/-0.008) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.559 (+/-0.004) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.648 (+/-0.013) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.670 (+/-0.014) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.550 (+/-0.008) for {'C': 1, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.558 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.563 (+/-0.014) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.683 (+/-0.016) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.683 (+/-0.011) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.580 (+/-0.017) for {'C': 10, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.560 (+/-0.006) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.667 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.695 (+/-0.026) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.667 (+/-0.011) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.580 (+/-0.017) for {'C': 100, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
# 0.576 (+/-0.024) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf', 'random_state': 42}
# 0.687 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf', 'random_state': 42}
# 0.698 (+/-0.027) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf', 'random_state': 42}
# 0.655 (+/-0.018) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf', 'random_state': 42}
# 0.580 (+/-0.016) for {'C': 1000, 'gamma': 1.0, 'kernel': 'rbf', 'random_state': 42}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# [[22744  3127]
#  [ 4188  4819]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86     25871
#            1       0.61      0.54      0.57      9007
#
#     accuracy                           0.79     34878
#    macro avg       0.73      0.71      0.71     34878
# weighted avg       0.78      0.79      0.79     34878
#
#
# CPU times: user 21min 42s, sys: 3.74 s, total: 21min 46s
# Wall time: 21min 48s

# %%
set(y_true)
# Out:
# {0, 1}
