# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/data.csv')
df_artist = pd.read_csv('dataset/data_by_artist.csv')
df_genre = pd.read_csv('dataset/data_by_genres.csv')
df_year = pd.read_csv('dataset/data_by_year.csv')

# %%
df = df.join(df_artist, rsuffix='_ar')

# %%
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790  ...
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809  ...
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190  ...
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280  ...
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020  ...
#
#    instrumentalness_ar  liveness_ar loudness_ar  speechiness_ar    tempo_ar  \
# 0             0.010261     0.283050  -14.434300        0.209150  114.128800
# 1             0.081158     0.315215  -10.690000        0.176212  103.044154
# 2             0.024593     0.325786  -15.230714        0.118514   77.375857
# 3             0.073587     0.275481  -15.639370        0.123200   88.667630
# 4             0.009400     0.195000  -10.236714        0.098543  122.835857
#
#    valence_ar  popularity_ar  key_ar  mode_ar count
# 0    0.358320      38.200000     5.0      1.0  10.0
# 1    0.268865      31.538462     5.0      1.0  26.0
# 2    0.354857      34.571429     0.0      1.0   7.0
# 3    0.372030      34.407407     0.0      1.0  27.0
# 4    0.482286      42.000000     5.0      1.0   7.0
#
# [5 rows x 34 columns]

# %%
df = df.join(df_year, rsuffix='_yr')

# %%
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790  ...
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809  ...
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190  ...
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280  ...
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020  ...
#
#    energy_yr  instrumentalness_yr liveness_yr  loudness_yr speechiness_yr  \
# 0   0.418700             0.354219    0.216049   -12.654020       0.082984
# 1   0.241136             0.337158    0.205219   -16.811660       0.078952
# 2   0.226173             0.254776    0.256662   -20.840083       0.464368
# 3   0.262406             0.371733    0.227462   -14.129211       0.093949
# 4   0.344347             0.581701    0.235219   -14.231343       0.092089
#
#      tempo_yr  valence_yr  popularity_yr  key_yr mode_yr
# 0  113.226900    0.498210       0.610315     2.0     1.0
# 1  102.425397    0.378276       0.391026     2.0     1.0
# 2  100.033149    0.571190       0.090909     5.0     1.0
# 3  114.010730    0.625492       5.205405     0.0     1.0
# 4  120.689572    0.663725       0.661017    10.0     1.0
#
# [5 rows x 48 columns]

# %%
df = df.join(df_genre, rsuffix='_gn')

# %%
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790  ...
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809  ...
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190  ...
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280  ...
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020  ...
#
#    energy_gn  instrumentalness_gn liveness_gn  loudness_gn speechiness_gn  \
# 0   0.159580             0.484374    0.168580   -22.153400       0.062060
# 1   0.391678             0.477250    0.265940   -18.131267       0.071717
# 2   0.950000             0.630000    0.069000    -7.899000       0.292000
# 3   0.485430             0.278442    0.220970   -11.624754       0.101511
# 4   0.330533             0.036080    0.222983   -12.656547       0.083627
#
#      tempo_gn  valence_gn  popularity_gn  key_gn mode_gn
# 0   91.351000    0.143380       6.600000     4.0     1.0
# 1  118.900933    0.236483      41.200000    11.0     1.0
# 2  192.816000    0.997000       0.000000     5.0     1.0
# 3  116.068980    0.486361      12.350770     7.0     1.0
# 4  105.506031    0.454077      39.086248     7.0     1.0
#
# [5 rows x 62 columns]

# %%
df.to_csv('dataset/data_merged.csv', index=False)
