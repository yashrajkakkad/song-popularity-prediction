# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('dataset/data.csv')
df_artist = pd.read_csv('dataset/data_by_artist.csv')
df_genre = pd.read_csv('dataset/data_by_genres.csv')
df_year = pd.read_csv('dataset/data_by_year.csv')

# %%
df['artists'] = df['artists'].apply(ast.literal_eval)

# %%
df['artists'] = df['artists'].map(lambda x : x[0])

# %%
df.head()
# Out:
#    acousticness                artists  danceability  duration_ms  energy  \
# 0      0.991000            Mamie Smith         0.598       168333   0.224
# 1      0.643000  Screamin' Jay Hawkins         0.852       150200   0.517
# 2      0.993000            Mamie Smith         0.647       163827   0.186
# 3      0.000173        Oscar Velazquez         0.730       422087   0.798
# 4      0.295000                   Mixe         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %%
print(type(df['artists'][0]), type(df_artist['artists'][0]))
# Out:
# <class 'str'> <class 'str'>

# %%
# Too slow, ignore
# for i in range(len(df['artists'])):
#     df['artists'][i] = df['artists'][i][0]
# Out:
# <ipython-input-26-b5a2c3c3e6e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['artists'][i] = df['artists'][i][0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b5a2c3c3e6e9> in <module>
#       1 for i in range(len(df['artists'])):
# ----> 2     df['artists'][i] = df['artists'][i][0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1043
#    1044         if cacher_needs_updating:
# -> 1045             self._maybe_update_cacher()
#    1046
#    1047     def _set_with_engine(self, key, value):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3280                 #  case where it will raise.  (Uh, not clear why)
#    3281                 try:
# -> 3282                     ref._maybe_cache_changed(cacher[0], self)
#    3283                 except AssertionError:
#    3284                     # ref._data.setitem can raise
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _maybe_cache_changed(self, item, value)
#    3239         """The object has called back to us saying maybe it has changed.
#    3240         """
# -> 3241         self._data.set(item, value)
#    3242
#    3243     @property
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1088             blk_locs = blklocs[val_locs.indexer]
#    1089             if blk.should_store(value):
# -> 1090                 blk.set(blk_locs, value_getitem(val_locs))
#    1091             else:
#    1092                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in set(self, locs, values)
#     374         None
#     375         """
# --> 376         self.values[locs] = values
#     377
#     378     def delete(self, loc):
#
# KeyboardInterrupt:

# %%
# type(df['artists'][0])

# %%
df_artist = df_artist.set_index('artists')

df = df.join(df_artist, on='artists', rsuffix='_ar')

# %%
df.iloc[:,19]
count_nan = len(df.iloc[:,19]) - df.iloc[:,19].count()
print(len(df), count_nan)
# Out:
# 174389 12

# %%
df.dropna(inplace=True)

# %%
len(df)
# Out:
# 174377

# %%
df.iloc[:,19]
# Out:
# 0         0.983000
# 1         0.738125
# 2         0.983000
# 3         0.000445
# 4         0.295000
#             ...
# 174384    0.007943
# 174385    0.446636
# 174386    0.265206
# 174387    0.280131
# 174388    0.265206
# Name: acousticness_ar, Length: 174389, dtype: float64

# %%
count_nan = len(df.iloc[:,19]) - df.iloc[:,19].count()
print(count_nan)
# Out:
# 12

# %%
df = df.join(df_year.set_index('year'), rsuffix='_yr', on='year')

# %%
df.head()
# Out:
#    acousticness                artists  danceability  duration_ms  energy  \
# 0      0.991000            Mamie Smith         0.598       168333   0.224
# 1      0.643000  Screamin' Jay Hawkins         0.852       150200   0.517
# 2      0.993000            Mamie Smith         0.647       163827   0.186
# 3      0.000173        Oscar Velazquez         0.730       422087   0.798
# 4      0.295000                   Mixe         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790  ...
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809  ...
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190  ...
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280  ...
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020  ...
#
#    energy_yr  instrumentalness_yr liveness_yr  loudness_yr speechiness_yr  \
# 0     0.4187             0.354219    0.216049    -12.65402       0.082984
# 1     0.4187             0.354219    0.216049    -12.65402       0.082984
# 2     0.4187             0.354219    0.216049    -12.65402       0.082984
# 3     0.4187             0.354219    0.216049    -12.65402       0.082984
# 4     0.4187             0.354219    0.216049    -12.65402       0.082984
#
#    tempo_yr  valence_yr  popularity_yr  key_yr  mode_yr
# 0  113.2269     0.49821       0.610315       2        1
# 1  113.2269     0.49821       0.610315       2        1
# 2  113.2269     0.49821       0.610315       2        1
# 3  113.2269     0.49821       0.610315       2        1
# 4  113.2269     0.49821       0.610315       2        1
#
# [5 rows x 46 columns]

# %%
count_nan = len(df) - df.count()
count_nan
# Out:
# acousticness           0
# artists                0
# danceability           0
# duration_ms            0
# energy                 0
# explicit               0
# id                     0
# instrumentalness       0
# key                    0
# liveness               0
# loudness               0
# mode                   0
# name                   0
# popularity             0
# release_date           0
# speechiness            0
# tempo                  0
# valence                0
# year                   0
# acousticness_ar        0
# danceability_ar        0
# duration_ms_ar         0
# energy_ar              0
# instrumentalness_ar    0
# liveness_ar            0
# loudness_ar            0
# speechiness_ar         0
# tempo_ar               0
# valence_ar             0
# popularity_ar          0
# key_ar                 0
# mode_ar                0
# count                  0
# acousticness_yr        0
# danceability_yr        0
# duration_ms_yr         0
# energy_yr              0
# instrumentalness_yr    0
# liveness_yr            0
# loudness_yr            0
# speechiness_yr         0
# tempo_yr               0
# valence_yr             0
# popularity_yr          0
# key_yr                 0
# mode_yr                0
# dtype: int64

# %%
# df = df.join(df_genre.set_index('genre'), rsuffix='_gn')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-6f4cd0658dc9> in <module>
# ----> 1 df = df.join(df_genre.set_index('genre'), rsuffix='_gn')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['genre'] are in the columns"

# %%
df.head()
# Out:
#    acousticness                artists  danceability  duration_ms  energy  \
# 0      0.991000            Mamie Smith         0.598       168333   0.224
# 1      0.643000  Screamin' Jay Hawkins         0.852       150200   0.517
# 2      0.993000            Mamie Smith         0.647       163827   0.186
# 3      0.000173        Oscar Velazquez         0.730       422087   0.798
# 4      0.295000                   Mixe         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790  ...
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809  ...
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190  ...
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280  ...
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020  ...
#
#    energy_yr  instrumentalness_yr liveness_yr  loudness_yr speechiness_yr  \
# 0     0.4187             0.354219    0.216049    -12.65402       0.082984
# 1     0.4187             0.354219    0.216049    -12.65402       0.082984
# 2     0.4187             0.354219    0.216049    -12.65402       0.082984
# 3     0.4187             0.354219    0.216049    -12.65402       0.082984
# 4     0.4187             0.354219    0.216049    -12.65402       0.082984
#
#    tempo_yr  valence_yr  popularity_yr  key_yr  mode_yr
# 0  113.2269     0.49821       0.610315       2        1
# 1  113.2269     0.49821       0.610315       2        1
# 2  113.2269     0.49821       0.610315       2        1
# 3  113.2269     0.49821       0.610315       2        1
# 4  113.2269     0.49821       0.610315       2        1
#
# [5 rows x 46 columns]

# %%
df.to_csv('dataset/data_merged.csv', index=False)
